# %%
import histomicstk
import openslide
import skimage
import pandas as pd
import numpy as np
# Out:
# INFO:root:Created LRU Cache for 'tilesource' with 204 maximum size
# INFO:root:Notice: Could not import PILFileTileSource

# %%
inputImageFile = "/media/jonny_admin/540GB/Research/TCGA_LUAD-WSI/TCGA-50-5066-01A-01-BS1.c6f25661-a8e9-4d89-9d16-0cfd1f4defe2.svs"
# imInput = skimage.io.imread(inputImageFile)[:, :, :3]
imInput = openslide.OpenSlide(inputImageFile)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5bce043b9316> in <module>()
#       1 inputImageFile = "/media/jonny_admin/540GB/Research/TCGA_LUAD-WSI/TCGA-50-5066-01A-01-BS1.c6f25661-a8e9-4d89-9d16-0cfd1f4defe2.svs"
#       2 # imInput = skimage.io.imread(inputImageFile)[:, :, :3]
# ----> 3 imInput = openslide.OpenSlide(inputImageFile)
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/openslide/__init__.pyc in __init__(self, filename)
#     152         AbstractSlide.__init__(self)
#     153         self._filename = filename
# --> 154         self._osr = lowlevel.open(filename)
#     155
#     156     def __repr__(self):
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/openslide/lowlevel.pyc in _check_open(result, _func, _args)
#     169
#     170 # check for errors opening an image file and wrap the resulting handle
# --> 171 def _check_open(result, _func, _args):
#     172     if result is None:
#     173         raise OpenSlideUnsupportedFormatError(
#
# KeyboardInterrupt:

# %%
imInput.properties
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5371435748ab> in <module>()
# ----> 1 imInput.properties
#
# NameError: name 'imInput' is not defined

# %%
biospecimen = pd.read_table("/home/jonny_admin/PycharmProjects/nuclei-segmentation/data/tcga-assembler/LUAD/clinical/" + "genome.wustl.edu_biospecimen_sample_luad.txt",
                                         sep="\t",
                                         skiprows=[1, ],
                                         na_values="[Not Available]",
                                         usecols=['bcr_sample_barcode', 'sample_type']
                                         )
biospecimen.index = biospecimen["bcr_sample_barcode"]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-40-4bbd4f1962e0> in <module>()
#       3                                          skiprows=[1, ],
#       4                                          na_values="[Not Available]",
# ----> 5                                          usecols=['bcr_sample_barcode', 'sample_type']
#       6                                          )
#       7 biospecimen.index = biospecimen["bcr_sample_barcode"]
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     703                     skip_blank_lines=skip_blank_lines)
#     704
# --> 705         return _read(filepath_or_buffer, kwds)
#     706
#     707     parser_f.__name__ = name
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     443
#     444     # Create the parser.
# --> 445     parser = TextFileReader(filepath_or_buffer, **kwds)
#     446
#     447     if chunksize or iterator:
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     812             self.options['has_index_names'] = kwds['has_index_names']
#     813
# --> 814         self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#    1043     def _make_engine(self, engine='c'):
#    1044         if engine == 'c':
# -> 1045             self._engine = CParserWrapper(self.f, **self.options)
#    1046         else:
#    1047             if engine == 'python':
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1682         kwds['allow_leading_cols'] = self.index_col is not False
#    1683
# -> 1684         self._reader = parsers.TextReader(src, **kwds)
#    1685
#    1686         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: File /home/jonny_admin/PycharmProjects/nuclei-segmentation/data/tcga-assembler/BLCA/clinical/nationwidechildrens.org_clinical_drug_blca.txt does not exist

# %%
table = pd.read_table("/home/jonny_admin/PycharmProjects/TCGA-Assembler/BLCA/clinical/nationwidechildrens.org_clinical_drug_blca.txt",
                      sep="\t", 
                      skiprows=[1, 2], 
                      na_values="[Not Available]"
                     )

# %%
# Filter columns
columns="GeneSymbol|TCGA"
# Filter columns
table = table.filter(regex=columns)

# Cut TCGA column names to sample barcode
table.rename(columns=lambda x: x[:16] if ("TCGA" in x) else x, inplace=True)

# Drop duplicate columns names (Gene symbols with same name)
_, i = np.unique(table.columns, return_index=True)
table = table.iloc[:, i]

# Drop NA GeneSymbol rows
table.dropna(axis=0, inplace=True)

# Remove entries with unknown Gene Symbol
table = table[table.GeneSymbol != '?']


# Transpose dataframe to patient rows and GeneSymbol columns
table.index = table.GeneSymbol
table.drop(['GeneSymbol'], axis=1, inplace=True)
table = table.T

# Add column for patients barcode
# table['bcr_sample_barcode'] = table.index

# Drop duplicate columns names (Gene symbols with same name)
_, i = np.unique(table.columns, return_index=True)
table = table.iloc[:, i]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-fa845cec4536> in <module>()
#      15
#      16 # Remove entries with unknown Gene Symbol
# ---> 17 table = table[table.GeneSymbol != '?']
#      18
#      19
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'GeneSymbol'

# %%
table
# Out:
#                          bcr_patient_uuid bcr_patient_barcode  \
# 0    a6003b1c-56a9-430a-a5e2-b70af3f81bdb        TCGA-BL-A0C8
# 1    ebedab7c-dd7c-448e-8324-78c86f13be8b        TCGA-BT-A20N
# 2    ebedab7c-dd7c-448e-8324-78c86f13be8b        TCGA-BT-A20N
# 3    096b4f32-10c1-4737-a0dd-cae04c54ee33        TCGA-BT-A20T
# 4    096b4f32-10c1-4737-a0dd-cae04c54ee33        TCGA-BT-A20T
# 5    096b4f32-10c1-4737-a0dd-cae04c54ee33        TCGA-BT-A20T
# 6    096b4f32-10c1-4737-a0dd-cae04c54ee33        TCGA-BT-A20T
# 7    096b4f32-10c1-4737-a0dd-cae04c54ee33        TCGA-BT-A20T
# 8    797A71EE-372D-41E5-AEEE-5AB3C4661110        TCGA-BT-A2LA
# 9    797A71EE-372D-41E5-AEEE-5AB3C4661110        TCGA-BT-A2LA
# 10   9DD97821-7AFD-4982-8B1D-F14F845B79F7        TCGA-BT-A2LD
# 11   9DD97821-7AFD-4982-8B1D-F14F845B79F7        TCGA-BT-A2LD
# 12   CB664EEF-BE6F-44EF-AA90-6F6DA0E6440A        TCGA-BT-A3PJ
# 13   CB664EEF-BE6F-44EF-AA90-6F6DA0E6440A        TCGA-BT-A3PJ
# 14   DB84C62D-6904-4EA8-8E51-1262B8D6FF90        TCGA-BT-A42B
# 15   DB84C62D-6904-4EA8-8E51-1262B8D6FF90        TCGA-BT-A42B
# 16   DB84C62D-6904-4EA8-8E51-1262B8D6FF90        TCGA-BT-A42B
# 17   8D434CFB-2414-4D93-BF79-7B957BF040DB        TCGA-BT-A42E
# 18   8D434CFB-2414-4D93-BF79-7B957BF040DB        TCGA-BT-A42E
# 19   05935f1d-77c2-46ca-b87a-7a84bce38afd        TCGA-C4-A0EZ
# 302  TCGA-ZF-AA5H-D72106  CAB786E1-619B-4568-A424-698490997C7B
#
#     form_completion_date pharmaceutical_therapy_drug_name  \
# 0              2012-6-13                              BCG
# 1              2013-6-27                           Gemzar
# 2              2013-6-27                        Cisplatin
# 3              2013-6-28                           Gemzar
# 4              2013-6-28                        Cisplatin
# 5              2013-6-28                        Docetaxel
# 6              2013-6-28                      Oxaliplatin
# 7              2013-6-28                        Cisplatin
# 8              2013-6-28                      Carboplatin
# 9              2013-6-28                         Etopside
# 10             2013-6-28                      Carboplatin
# 11             2013-6-28                            Taxol
# 12              2012-7-5                      Gemcitabine
# 13              2012-7-5                      Carboplatin
# 14             2013-4-22                      Gemcitabine
# 15             2013-4-22                        Cisplatin
# 16             2013-4-22                            Taxol
# 17            2013-10-17                      Carboplatin
# 18            2013-10-17                           Gemzar
# 19             2012-12-5                      Carboplatin
# 20             2012-12-5                        Etoposide
# 21             2012-12-5                      Doxorubicin
# 22             2014-3-31   Bacillus Calmette-Guerin (BCG)
# 23             2014-3-31                      Doxobubicin
# 24             2014-3-31                      Carboplatin
# 25             2014-3-31                              5FU
# 26             2012-9-24                      Gemcitabine
# 27             2012-9-24                        Cisplatin
# 28             2012-2-15                      Gemcitabine
# 29              2015-7-8                        Cisplatin
# ..                   ...                              ...
# 273            2014-7-19         Adriamycin (doxorubicin)
# 274            2014-7-19                      Gemcitabine
# 275            2014-7-19         Adriamycin (doxorubicin)
# 276            2014-7-19                     Temsirolimus
# 277            2014-7-19                      Vinorelbine
# 278            2014-7-16                              BCG
# 279            2014-7-16                              BCG
# 280            2014-7-20                        Cisplatin
# 281            2014-7-20                      Gemcitabine
# 282            2014-7-20                        Cisplatin
# 283            2014-7-20                      Gemcitabine
# 284            2014-7-21                        Cisplatin
# 285            2014-7-21                      Gemcitabine
# 286            2014-7-21                       Ifosfamide
# 287            2014-7-21                       Paclitaxel
# 288            2014-7-21                        Cisplatin
# 289            2014-7-21            Docetaxel +/- Zactima
# 290           2014-11-11                        cisplatin
# 291           2014-11-11                           Gemzar
# 292            2014-5-23                        Cisplatin
# 293            2014-5-23                      Gemcitabine
# 294            2015-4-10        Gemcitabine and Cisplatin
# 295            2015-4-10                      Gemcitabine
# 296            2015-4-10                        Cisplatin
# 297            2015-4-10                      Gemcitabine
# 298            2015-4-10                        Cisplatin
# 299            2015-4-13                      Gemcitabine
# 300            2015-4-13                        Cisplatin
# 301            2015-4-13                      Gemcitabine
# 302            2015-4-13                        Cisplatin
#
#                     clinical_trial_drug_classification  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                     mTOR inhibitor
# 277                       anti-mitotic, vinca alkaloid
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289  Blinded: Zactima or Placebo. Zactima is a kina...
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
# 301                                                NaN
# 302                                                NaN
#
#     pharmaceutical_therapy_type  pharmaceutical_tx_started_days_to  \
# 0                 Immunotherapy                              680.0
# 1                  Chemotherapy                              198.0
# 2                  Chemotherapy                              198.0
# 3                  Chemotherapy                              161.0
# 4                  Chemotherapy                              161.0
# 5                  Chemotherapy                              263.0
# 6                  Chemotherapy                              263.0
# 7                  Chemotherapy                              419.0
# 8                  Chemotherapy                               96.0
# 9                  Chemotherapy                               96.0
# 10                 Chemotherapy                              458.0
# 11                 Chemotherapy                              458.0
# 12                 Chemotherapy                               68.0
# 13                 Chemotherapy                               68.0
# 14                 Chemotherapy                              121.0
# 15                 Chemotherapy                              121.0
# 16                 Chemotherapy                              121.0
# 17                 Chemotherapy                               49.0
# 18                 Chemotherapy                               49.0
# 19                 Chemotherapy                              123.0
# 20                 Chemotherapy                              123.0
# 21                 Chemotherapy                              243.0
# 22                Immunotherapy                              109.0
# 23                 Chemotherapy                              109.0
# 24                 Chemotherapy                              127.0
# 25                 Chemotherapy                              127.0
# 26                 Chemotherapy                              155.0
# 27                 Chemotherapy                              155.0
# 28                 Chemotherapy                              133.0
# 29                 Chemotherapy                              133.0
# ..                          ...                                ...
# 273                Chemotherapy                             1465.0
# 274                Chemotherapy                             1598.0
# 275                Chemotherapy                             1598.0
# 276                Chemotherapy                             1703.0
# 277                Chemotherapy                             1703.0
# 278               Immunotherapy                                0.0
# 279               Immunotherapy                                0.0
# 280                Chemotherapy                              121.0
# 281                Chemotherapy                              121.0
# 282                Chemotherapy                              127.0
# 283                Chemotherapy                              127.0
# 284                Chemotherapy                              162.0
# 285                Chemotherapy                              162.0
# 286                Chemotherapy                              351.0
# 287                Chemotherapy                                0.0
# 288                Chemotherapy                                0.0
# 289                Chemotherapy                              399.0
# 290                Chemotherapy                               35.0
# 291                Chemotherapy                               35.0
# 292                Chemotherapy                              215.0
# 293                Chemotherapy                              214.0
# 294                Chemotherapy                              202.0
# 295                Chemotherapy                               69.0
# 296                Chemotherapy                               69.0
# 297                Chemotherapy                               68.0
# 298                Chemotherapy                               68.0
# 299                Chemotherapy                              166.0
# 300                Chemotherapy                              166.0
# 301                Chemotherapy                              135.0
# 302                Chemotherapy                              135.0
#
#     pharmaceutical_tx_ongoing_indicator          ...           \
# 0                                    NO          ...
# 1                                    NO          ...
# 2                                    NO          ...
# 3                                    NO          ...
# 4                                    NO          ...
# 5                                    NO          ...
# 6                                    NO          ...
# 7                                    NO          ...
# 8                                    NO          ...
# 9                                    NO          ...
# 10                                   NO          ...
# 11                                   NO          ...
# 12                                  YES          ...
# 13                                  YES          ...
# 14                                   NO          ...
# 15                                   NO          ...
# 16                                   NO          ...
# 17                                   NO          ...
# 18                                   NO          ...
# 19                                   NO          ...
# 20                                   NO          ...
# 21                                   NO          ...
# 22                                   NO          ...
# 23                                   NO          ...
# 24                                   NO          ...
# 25                                   NO          ...
# 26                                   NO          ...
# 27                                   NO          ...
# 28                                   NO          ...
# 29                                   NO          ...
# ..                                  ...          ...
# 273                                  NO          ...
# 274                                  NO          ...
# 275                                  NO          ...
# 276                                  NO          ...
# 277                                  NO          ...
# 278                                  NO          ...
# 279                                  NO          ...
# 280                                  NO          ...
# 281                                  NO          ...
# 282                                  NO          ...
# 283                                  NO          ...
# 284                                  NO          ...
# 285                                  NO          ...
# 286                                  NO          ...
# 287                                  NO          ...
# 288                                  NO          ...
# 289                                  NO          ...
# 290                                  NO          ...
# 291                                  NO          ...
# 292                                 YES          ...
# 293                                 YES          ...
# 294                                  NO          ...
# 295                                  NO          ...
# 296                                  NO          ...
# 297                                  NO          ...
# 298                                  NO          ...
# 299                                  NO          ...
# 300                                  NO          ...
# 301                                  NO          ...
# 302                                  NO          ...
#
#      pharmaceutical_tx_total_dose_units prescribed_dose  regimen_number  \
# 0                                   NaN             NaN             NaN
# 1                                   NaN             NaN             NaN
# 2                                   NaN             NaN             NaN
# 3                                   NaN             NaN             NaN
# 4                                   NaN             NaN             NaN
# 5                                   NaN             NaN             NaN
# 6                                   NaN             NaN             NaN
# 7                                   NaN             NaN             NaN
# 8                                   NaN             NaN             NaN
# 9                                   NaN             NaN             NaN
# 10                                  NaN             NaN             NaN
# 11                                  NaN             NaN             NaN
# 12                                  NaN             NaN             NaN
# 13                                  NaN             NaN             NaN
# 14                                  NaN             NaN             NaN
# 15                                  NaN             NaN             NaN
# 16                                  NaN             NaN             NaN
# 17                                  NaN             NaN             NaN
# 18                                  NaN             NaN             NaN
# 19                                  NaN             NaN             NaN
# 20                                  NaN             NaN             NaN
# 21                                  NaN             NaN             NaN
# 22                                  NaN             NaN             NaN
# 23                                  NaN             NaN             NaN
# 24                                  NaN             NaN             NaN
# 25                                  NaN             NaN             NaN
# 26                                  NaN             NaN             NaN
# 27                                  NaN             NaN             NaN
# 28                                   mg          1000.0        1st Line
# 29                                  NaN             NaN             NaN
# ..                                  ...             ...             ...
# 273                                 NaN             NaN             NaN
# 274                                 NaN             NaN             NaN
# 275                                 NaN             NaN             NaN
# 276                                 NaN             NaN             NaN
# 277                                 NaN             NaN             NaN
# 278                                 NaN             NaN             NaN
# 279                                 NaN             NaN             NaN
# 280                                 NaN             NaN             NaN
# 281                                 NaN             NaN             NaN
# 282                                 NaN             NaN             NaN
# 283                                 NaN             NaN             NaN
# 284                                 NaN             NaN             NaN
# 285                                 NaN             NaN             NaN
# 286                                 NaN             NaN             NaN
# 287                                 NaN             NaN             NaN
# 288                                 NaN             NaN             NaN
# 289                                 NaN             NaN             NaN
# 290                                 NaN             NaN             NaN
# 291                                 NaN             NaN             NaN
# 292                                 NaN             NaN             NaN
# 293                                 NaN             NaN             NaN
# 294                                 NaN             NaN             NaN
# 295                                 NaN             NaN             NaN
# 296                                 NaN             NaN             NaN
# 297                                 NaN             NaN             NaN
# 298                                 NaN             NaN             NaN
# 299                                 NaN             NaN             NaN
# 300                                 NaN             NaN             NaN
# 301                                 NaN             NaN             NaN
# 302                                 NaN             NaN             NaN
#
#      route_of_administration  stem_cell_transplantation  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
# 10                       NaN                        NaN
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 13                       NaN                        NaN
# 14                       NaN                        NaN
# 15                       NaN                        NaN
# 16                       NaN                        NaN
# 17                       NaN                        NaN
# 18                       NaN                        NaN
# 19                       NaN                        NaN
# 20                       NaN                        NaN
# 21                       NaN                        NaN
# 22                       NaN                        NaN
# 23                       NaN                        NaN
# 24                       NaN                        NaN
# 25                       NaN                        NaN
# 26                       NaN                        NaN
# 27                       NaN                        NaN
# 291                             NaN              NaN      [Not Applicable]
# 292                             NaN              NaN      [Not Applicable]
# 293                             NaN              NaN      [Not Applicable]
# 294                             NaN              NaN      [Not Applicable]
# 295                             NaN              NaN      [Not Applicable]
# 296                             NaN              NaN      [Not Applicable]
# 297                             NaN              NaN      [Not Applicable]
# 298                             NaN              NaN      [Not Applicable]
# 299                             NaN              NaN      [Not Applicable]
# 300                             NaN              NaN      [Not Applicable]
# 301                             NaN              NaN      [Not Applicable]
# 302                             NaN              NaN      [Not Applicable]
#
#     total_dose  tx_on_clinical_trial
# 0          NaN                    NO
# 1          NaN                    NO
# 2          NaN                    NO
# 3          NaN                    NO
# 4          NaN                    NO
# 5          NaN                   YES
# 6          NaN                   YES
# 7          NaN                    NO
# 8          NaN                    NO
# 9          NaN                    NO
# 10         NaN                    NO
# 11         NaN                    NO
# 12         NaN                    NO
# 13         NaN                    NO
# 14         NaN                    NO
# 15         NaN                    NO
# 16         NaN                    NO
# 17         NaN                    NO
# 18         NaN                    NO
# 19         NaN                    NO
# 20         NaN                    NO
# 21         NaN                    NO
# 22         NaN                    NO
# 23         NaN                    NO
# 24         NaN                    NO
# 25         NaN                    NO
# 26         NaN                    NO
# 27         NaN                    NO
# 28      1300.0                   NaN
# 29         NaN                    NO
# ..         ...                   ...
# 273        NaN                    NO
# 274        NaN                    NO
# 275        NaN                    NO
# 276        NaN                   YES
# 277        NaN                   YES
# 278        NaN                    NO
# 279        NaN                    NO
# 280        NaN                    NO
# 281        NaN                    NO
# 282        NaN                    NO
# 283        NaN                    NO
# 284        NaN                    NO
# 285        NaN                    NO
# 286        NaN                    NO
# 287        NaN                    NO
# 288        NaN                    NO
# 289        NaN                   YES
# 290        NaN                    NO
# 291        NaN                    NO
# 292        NaN                    NO
# 293        NaN                    NO
# 294        NaN                    NO
# 295        NaN                    NO
# 296        NaN                    NO
# 297        NaN                    NO
# 298        NaN                    NO
# 299        NaN                    NO
# 300        NaN                    NO
# 301        NaN                    NO
# 302        NaN                    NO
#
# [303 rows x 28 columns]

# %%
table["pharmaceutical_therapy_type"].value_counts()
# Out:
# Chemotherapy     283
# Immunotherapy      9
# Ancillary          2
# Name: pharmaceutical_therapy_type, dtype: int64

# %%
list(table.columns)
# Out:
# ['bcr_patient_uuid',
#  'bcr_patient_barcode',
#  'bcr_drug_barcode',
#  'bcr_drug_uuid',
#  'form_completion_date',
#  'pharmaceutical_therapy_drug_name',
#  'clinical_trial_drug_classification',
#  'pharmaceutical_therapy_type',
#  'pharmaceutical_tx_started_days_to',
#  'pharmaceutical_tx_ongoing_indicator',
#  'pharmaceutical_tx_ended_days_to',
#  'treatment_best_response',
#  'days_to_stem_cell_transplantation',
#  'pharm_regimen',
#  'pharm_regimen_other',
#  'pharma_adjuvant_cycles_count',
#  'pharma_type_other',
#  'pharmaceutical_tx_dose_units',
#  'pharmaceutical_tx_total_dose_units',
#  'prescribed_dose',
#  'regimen_number',
#  'route_of_administration',
#  'stem_cell_transplantation',
#  'stem_cell_transplantation_type',
#  'therapy_regimen',
#  'therapy_regimen_other',
#  'total_dose',
#  'tx_on_clinical_trial']
