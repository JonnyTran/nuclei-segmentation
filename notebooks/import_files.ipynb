# %%
import histomicstk
import openslide
import skimage
import pandas as pd
import numpy as np

# %%
inputImageFile = "/media/jonny_admin/540GB/Research/TCGA_LUAD-WSI/TCGA-50-5066-01A-01-BS1.c6f25661-a8e9-4d89-9d16-0cfd1f4defe2.svs"
# imInput = skimage.io.imread(inputImageFile)[:, :, :3]
imInput = openslide.OpenSlide(inputImageFile)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5bce043b9316> in <module>()
#       1 inputImageFile = "/media/jonny_admin/540GB/Research/TCGA_LUAD-WSI/TCGA-50-5066-01A-01-BS1.c6f25661-a8e9-4d89-9d16-0cfd1f4defe2.svs"
#       2 # imInput = skimage.io.imread(inputImageFile)[:, :, :3]
# ----> 3 imInput = openslide.OpenSlide(inputImageFile)
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/openslide/__init__.pyc in __init__(self, filename)
#     152         AbstractSlide.__init__(self)
#     153         self._filename = filename
# --> 154         self._osr = lowlevel.open(filename)
#     155
#     156     def __repr__(self):
#
# /opt/anaconda3/envs/py27/lib/python2.7/site-packages/openslide/lowlevel.pyc in _check_open(result, _func, _args)
#     169
#     170 # check for errors opening an image file and wrap the resulting handle
# --> 171 def _check_open(result, _func, _args):
#     172     if result is None:
#     173         raise OpenSlideUnsupportedFormatError(
#
# KeyboardInterrupt:

# %%
imInput.properties
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5371435748ab> in <module>()
# ----> 1 imInput.properties
#
# NameError: name 'imInput' is not defined

# %%
biospecimen = pd.read_table("/home/jonny_admin/PycharmProjects/nuclei-segmentation/data/tcga-assembler/LUAD/clinical/" + "genome.wustl.edu_biospecimen_sample_luad.txt",
                                         sep="\t",
                                         skiprows=[1, ],
                                         na_values="[Not Available]",
                                         usecols=['bcr_sample_barcode', 'sample_type']
                                         )
biospecimen.index = biospecimen["bcr_sample_barcode"]

# %%
table = pd.read_table("/home/jonny_admin/PycharmProjects/nuclei-segmentation/data/tcga-assembler/LUAD/cnv/LUAD__copyNumber.txt",
                      sep="\t", 
#                       skiprows=[1,], 
#                       na_values="[Not Available]"
                     )

# %%
# Filter columns
columns="GeneSymbol|TCGA"
# Filter columns
table = table.filter(regex=columns)

# Cut TCGA column names to sample barcode
table.rename(columns=lambda x: x[:16] if ("TCGA" in x) else x, inplace=True)

# Drop duplicate columns names (Gene symbols with same name)
_, i = np.unique(table.columns, return_index=True)
table = table.iloc[:, i]

# Drop NA GeneSymbol rows
table.dropna(axis=0, inplace=True)

# Remove entries with unknown Gene Symbol
table = table[table.GeneSymbol != '?']


# Transpose dataframe to patient rows and GeneSymbol columns
table.index = table.GeneSymbol
table.drop(['GeneSymbol'], axis=1, inplace=True)
table = table.T

# Add column for patients barcode
# table['bcr_sample_barcode'] = table.index

# Drop duplicate columns names (Gene symbols with same name)
_, i = np.unique(table.columns, return_index=True)
table = table.iloc[:, i]

# %%
table.index
# Out:
# Index(['TCGA-05-4244-01A', 'TCGA-05-4249-01A', 'TCGA-05-4249-10A',
11A  Solid Tissue Normal   NaN       NaN
# TCGA-17-Z061-01A     TCGA-17-Z061-01A        Primary Tumor   NaN       NaN
# TCGA-17-Z061-11A     TCGA-17-Z061-11A  Solid Tissue Normal   NaN       NaN
# TCGA-17-Z062-01A     TCGA-17-Z062-01A        Primary Tumor   NaN       NaN
# TCGA-17-Z062-11A     TCGA-17-Z062-11A  Solid Tissue Normal   NaN       NaN
#
#                     A1CF  A2M  A2M-AS1  A2ML1  A2MP1  A4GALT  ...   ZWILCH  \
# bcr_sample_barcode                                            ...
# TCGA-17-Z000-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z000-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z001-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z001-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z002-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z002-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z003-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z003-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z004-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z004-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z005-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z005-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z006-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z006-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z007-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z007-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z008-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z008-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z009-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z009-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z010-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z010-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z011-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z011-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z012-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z012-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z013-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z013-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z014-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z014-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# ...                  ...  ...      ...    ...    ...     ...  ...      ...
# TCGA-17-Z048-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z048-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z049-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z049-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z050-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z050-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z051-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z051-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z052-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z052-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z053-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z053-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z054-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z054-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z055-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z055-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z056-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z056-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z057-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z057-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z058-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z058-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z059-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z059-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z060-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z060-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z061-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z061-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z062-01A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
# TCGA-17-Z062-11A     NaN  NaN      NaN    NaN    NaN     NaN  ...      NaN
#
#                     ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  ZYX  ZZEF1  ZZZ3
# bcr_sample_barcode
# TCGA-17-Z000-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z000-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z001-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z001-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z002-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z002-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z003-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z003-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z004-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z004-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z005-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z005-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z006-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z006-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z007-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z007-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z008-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z008-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z009-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z009-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z010-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z010-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z011-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z011-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z012-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z012-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z013-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z013-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z014-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z014-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# ...                   ...   ...   ...   ...     ...     ...  ...    ...   ...
# TCGA-17-Z048-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z048-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z049-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z049-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z050-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z050-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z051-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z051-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z052-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z052-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z053-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z053-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z054-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z054-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z055-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z055-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z056-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z056-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z057-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z057-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z058-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z058-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z059-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z059-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z060-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z060-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z061-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z061-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z062-01A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
# TCGA-17-Z062-11A      NaN   NaN   NaN   NaN     NaN     NaN  NaN    NaN   NaN
#
# [126 rows x 22518 columns]

# %%
list(table.columns)
# Out:
# ['bcr_patient_uuid',
#  'bcr_patient_barcode',
#  'b_cell_tumor_slide_submitted',
#  'consent_or_death_status',
#  'country',
#  'days_to_pathology_review',
#  'days_to_sample_procurement',
#  'digital_image_submitted',
#  'ethnicity',
#  'ffpe_tumor_slide_submitted',
#  'frozen_specimen_anatomic_site',
#  'histological_type',
#  'histological_type_other',
#  'history_of_neoadjuvant_treatment',
#  'hiv_positive_status',
#  'maximum_tumor_dimension',
#  'method_of_sample_procurement',
#  'other_method_of_sample_procurement',
#  'other_vessel_used',
#  'path_confirm_diagnosis_matching',
#  'path_confirm_report_attached',
#  'path_confirm_tumor_necrosis_metrics',
#  'path_confirm_tumor_nuclei_metrics',
#  'race',
#  'reason_path_confirm_diagnosis_not_matching',
#  'sample_prescreened',
#  'submitted_for_lce',
#  't_cell_tumor_slide_submitted',
#  'top_slide_submitted',
#  'vessel_used']
